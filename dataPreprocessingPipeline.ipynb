# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

# %%
# handling missing values

df.isnull() # true for null val
df.isna() # another aisle for the same 
df.isnull().sum() # no. null val w.r.t col val
df.dropna() # drop all rows having null  drop
df.dropna(axis = 1) # drop all col having null

# %%
#handling duplicates 
df.duplicated() # col wise
df[["country" , "gender"]].duplicated()

df.drop_duplicates() # does not change in org file

#to change in org file
df2 = df.copy()
df.drop_duplicates(inplace = True) # generally not advisable to change in org data due to recovery of old data

# %%
#data types
df.dtypes # data type w r t col

df2 = df.copy()
df2 = df2.fillna(0)
df2["age"] = df2["age"].astype("int64") # to change data type 
df2.dtypes

# datetime - change datatype into datetime
date_str = "2005-02-22"
type(date_str) # str

date_str = pd.Series(["2005-02-22"])
type(date_str)  #series

date_str = pd.Series(pd.to_datetime(["2005-02-22"]))
type(date_str.dtypes) # date time
# Out:
# numpy.dtypes.DateTime64DType

# %%
#handles strings

df["gender"].str.upper()
df["country"].str.lower()
df["name"].str.capitalize()

#split 
df["name"].str.split(" ")

#contains
df["country"].str.contains("india" , case = False)
# Out:
# 0     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# Name: country, dtype: bool

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# featuring engineering
#apply
df2 = df.copy();
df2["tax"] = df2["income"].apply(lambda x :"20%" if x > 50000 else "10%")
df2

#mapping : suppose male - m ....
#create a dictionary
gender_map = {"Male" : "M" , "Female" : "F", "Unknown" : "U"}
df2["gender"] = df2["gender"].map(gender_map)
df2

#assign - to create new col 
df2 = df2.assign(new_income = df2["income"] * 1.1)
df2

# replace the value
df2["country"] = df2["country"].replace("USA","united states")
df2

#replace the coloum with new
df2.columns = ["ID", "NAME", "AGE","COUNTRY", "GENDER" , "INCOME", "TAX", "NEW_INCOME"]  #to change col name
df2.rename(columns = {"INCOME" : "salary"}) # to change part col name
df2.rename(index = {2: "second"})

#sort 
df2.sort_values("INCOME") # sorted acc to income
df2 ["AGE"] = df2["AGE"].fillna(100)
#sorted_df2 = df2.sort_values(["INCOME", "AGE"]) # if income is same then acc to age

sorted_df2.sort_index() # sorted index all info like before

# to rest only index with modified data 
sorted_df2.reset_index()
# to drop thr org index
sorted_df2.reset_index(drop = True)

#ranking
sorted_df2["INCOME"]= sorted_df2["INCOME"].fillna(500)
sorted_df2
sorted_df2["NEW_INCOME"] = sorted_df2["INCOME"] * 1.1
sorted_df2["INCOME"].rank(ascending = False , method = "max")
sorted_df2[["ID", "NAME", "AGE","COUNTRY", "GENDER" , "INCOME", "NEW_INCOME", "TAX"]] # simply change the order here

# %%
df2
# Out:
#     ID          NAME    AGE        COUNTRY GENDER   INCOME  TAX  NEW_INCOME
# 0    1      John Doe   29.0  united states      M  55000.0  20%     60500.0
# 2    2    Jane Smith  100.0         Canada      F  62000.0  20%     68200.0
# 3    3          Alex  100.0  united states      U  47000.0  10%     51700.0
# 4    4  Maria Garcia   34.0          Spain      F      NaN  10%         NaN
# 5    5        Li Wei   27.0          China      M  51000.0  20%     56100.0
# 6    6           NaN   45.0          India      F  73000.0  20%     80300.0
# 7    7    Ahmed Khan   38.0            NaN      M  68000.0  20%     74800.0
# 8    8    Rachel Lee   29.0  united states      F  62000.0  20%     68200.0
# 9    9   Carlos Ruiz  100.0         Mexico      M  45000.0  10%     49500.0
# 10  10   Emily Davis   31.0  united states    NaN  58000.0  20%     63800.0

# %%
df.columns = [["name", "age", "country", "gender", "income", "id"]]
df
# Out:
#    name           age country  gender   income       id
# 0     1      John Doe    29.0     USA     Male  55000.0
# 2     2    Jane Smith     NaN  Canada   Female  62000.0
# 3     3          Alex     NaN     USA  Unknown  47000.0
# 4     4  Maria Garcia    34.0   Spain   Female      NaN
# 5     5        Li Wei    27.0   China     Male  51000.0
# 6     6           NaN    45.0   India   Female  73000.0
# 7     7    Ahmed Khan    38.0     NaN     Male  68000.0
# 8     8    Rachel Lee    29.0     USA   Female  62000.0
# 9     9   Carlos Ruiz     NaN  Mexico     Male  45000.0
# 10   10   Emily Davis    31.0     USA      NaN  58000.0

# %%
df1 = df.copy()
#error - tuples - or flatten the col first
df1.columns = [col[0] for col in df1.columns]
new_col_order = [col for col in df1.columns if col != "id"] + ["id"]
# new_col_order = [ col for col in df1.columns if col != ('id',)] + [("id",)]  # errored in tupples either like this
print(new_col_order)
df1[new_col_order]
# Out:
# ['name', 'age', 'country', 'gender', 'income', 'id']
#     name           age  country  gender   income       id
# 0      1      John Doe     29.0     USA     Male  55000.0
# 2      2    Jane Smith      NaN  Canada   Female  62000.0
# 3      3          Alex      NaN     USA  Unknown  47000.0
# 4      4  Maria Garcia     34.0   Spain   Female      NaN
# 5      5        Li Wei     27.0   China     Male  51000.0
# 6      6           NaN     45.0   India   Female  73000.0
# 7      7    Ahmed Khan     38.0     NaN     Male  68000.0
# 8      8    Rachel Lee     29.0     USA   Female  62000.0
# 9      9   Carlos Ruiz      NaN  Mexico     Male  45000.0
# 10    10   Emily Davis     31.0     USA      NaN  58000.0

# %%
dff = pd.read_csv("raw_data.csv")
dff1 = dff.copy()
dff1.duplicated()
dff1.drop_duplicates()

dff1["name"] = dff1["name"].fillna("xxx")
dff1["age"] = dff1["age"].fillna(dff1["age"].mean())
dff1["gender"] = dff1["gender"].fillna("alien")
dff1["income"] = dff1["income"].fillna(dff1["income"].mean())

# dff1.columns = [["ID", "NAME" , "AGE","COUNTRY", "GENDER", "INCOME"]]

sorted_val = dff1.sort_values("income")
sorted_val = sorted_val.reset_index(drop = True)
sorted_val.to_csv("sorted_data.csv")

# %%
# group by to make a parameter group and perform func
df.groupby("country")
df.groupby("country")["income"].mean()# mean of income of country
df.groupby("country")["income"].max()
df.groupby("country")["income"].min()
df.groupby("country")["income"].sum()

df.groupby("gender")["income"].mean()
df.groupby("gender")["income"].mean()

df.groupby("country")["income"].agg(["mean","max","min"])
df.groupby("country")["income"].aggregate(avg_salary = "mean", max_income = "max", min_income = "min")

df.groupby("country").agg({
    "income" : "max",
    "age" :"mean"
})

df.groupby("country").aggregate(
    max_income = ("income" , "max"),
    mean_age = ("age" ,"mean")
)

# %%
dff
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
# melted - converting wide data into long
melted_data = dff.melt(
    id_vars = ["id", "name", "country"], #keeps the column
    value_vars = [ "age", "gender" , "income"], # convert into rows
    var_name = "info", # converted row under which col name
    value_name = "values" # value col name of converted row
)

melted_data
# Out:
#     id          name country    info   values
# 0    1      John Doe     USA     age     29.0
# 1    1      John Doe     USA     age     29.0
# 2    2    Jane Smith  Canada     age      NaN
# 3    3          Alex     USA     age      NaN
# 4    4  Maria Garcia   Spain     age     34.0
# 5    5        Li Wei   China     age     27.0
# 6    6           NaN   India     age     45.0
# 7    7    Ahmed Khan     NaN     age     38.0
# 8    8    Rachel Lee     USA     age     29.0
# 9    9   Carlos Ruiz  Mexico     age      NaN
# 10  10   Emily Davis     USA     age     31.0
# 11   1      John Doe     USA  gender     Male
# 12   1      John Doe     USA  gender     Male
# 13   2    Jane Smith  Canada  gender   Female
# 14   3          Alex     USA  gender  Unknown
# 15   4  Maria Garcia   Spain  gender   Female
# 16   5        Li Wei   China  gender     Male
# 17   6           NaN   India  gender   Female
# 18   7    Ahmed Khan     NaN  gender     Male
# ...

# %%
# pivot - converts long data into wide
orignal = melted_data.pivot(
    index = ["id","country", "name"], # keeps col
    columns = "info", # make col
    values = "values", # values converted col
    
)
orignal

# %%
#basic visualization 
df = pd.read_csv("globalAirQuality.csv")

# to plot histogram
df["country"].hist()

df_plot = df.plot( kind = "scatter" , x = "humidity", y = "aqi")

# %%
# merging and joining data 

df_customers = ({
    "customer_id" : [1, 2, 3, 4],
    "name " : ["palak", "purvi " , "sakshi" , "hina" ]
})

df_order= ({
    "order_id" :[1020,102,105,106],
    "customer_id" : [1, 5, 3, 2],
    "amount" : [ 150,2500,6320,4251]
})
df1 = pd.DataFrame(df_customers)
df2 = pd.DataFrame(df_order)

pd.merge(df1, df2, on = "customer_id") # common in both  - inner join
pd.merge(df1, df2, on = "customer_id" , how = "left") #left join = left df1
pd.merge(df1, df2, on = "customer_id" , how = "right")#right join = right df2
pd.merge(df1, df2, on = "customer_id" , how = "outer")#outer - both left and right
# Out:
#    customer_id   name   order_id  amount
# 0            1   palak    1020.0   150.0
# 1            2  purvi      106.0  4251.0
# 2            3  sakshi     105.0  6320.0
# 3            4    hina       NaN     NaN
# 4            5     NaN     102.0  2500.0

# %%
# data concatenation  - either by row(in stack) or column(side by side)
df1 = pd.DataFrame({
    "id" : [1, 2, 3, 4],
    "name" :["mansi" , "rahul " , "raghav", "romeo"]
})

df2 = pd.DataFrame({
    "id" : [4, 5, 6, 7],
    "name" :[" romeo ","saves ","me ","wecanbe"]
})

pd.concat([df1,df2])
pd.concat([df1,df2], axis = 1) #col as side by side
# Out:
#    id    name  id     name
# 0   1   mansi   4   romeo
# 1   2  rahul    5   saves
# 2   3  raghav   6      me
# 3   4   romeo   7  wecanbe

# %%
pd.concat([df1,df2], ignore_index = True) # row as stack
# Out:
#    id     name
# 0   1    mansi
# 1   2   rahul
# 2   3   raghav
# 3   4    romeo
# 4   4   romeo
# 5   5   saves
# 6   6      me
# 7   7  wecanbe
